# %% [markdown]
# # Facial Emotions Detection using Convolutional Neural Network(CNN)

# %% [markdown]
# # 1.Objectives
#
# 1. To apply Convolutional neural networks (CNN) for facial expression/emotions recognition.
#
# 2. To correctly classify each facial image into one of the seven facial emotion categories:
#     **anger, disgust, fear, happiness, sadness, surprise, and neutral.**
#
# 3. The training set consists of 28,709 examples and the public test set consists of 7,178 examples.

# %% [markdown]
# # 2.Import Python modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pathlib

from sklearn.preprocessing import StandardScaler

import cv2
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # 3. Load the dataset

# %%
train_data_dir = pathlib.Path("../input/d/msambare/fer2013/train")
print(train_data_dir)

test_data_dir = pathlib.Path("../input/d/msambare/fer2013/test")
print(test_data_dir)
# Out:
# ../input/d/msambare/fer2013/train
# ../input/d/msambare/fer2013/test

# %%
# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all test images
train_generator = train_data_gen.flow_from_directory(
        '../input/d/msambare/fer2013/train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# Preprocess all train images
validation_generator = validation_data_gen.flow_from_directory(
        '../input/d/msambare/fer2013/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4.Build convolutional neural network

# %% [markdown]
# **CNN Architecture:**
#
#     Conv -> Activation
#     Conv -> Activation
#     MaxPooling
#     Dropout
#
#     Conv -> Activation
#     MaxPooling
#     Conv -> Activation
#     Dropout
#
#     Flatten
#     Dense ->  Activation
#     Dropout
#     Dense ->  Activation
#     Output layer

# %%
# create model structure
emotion_model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

emotion_model.compile(optimizer='adam',
              loss="categorical_crossentropy",
              metrics=['accuracy'])

emotion_model.summary()

# Train the neural network/model
emotion_model_info = emotion_model.fit(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 2,345,607
# Trainable params: 2,345,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 448/448 [==============================] - 120s 252ms/step - loss: 1.7165 - accuracy: 0.3049 - val_loss: 1.5174 - val_accuracy: 0.4155
# Epoch 2/50
# 448/448 [==============================] - 31s 68ms/step - loss: 1.4284 - accuracy: 0.4463 - val_loss: 1.2931 - val_accuracy: 0.5035
# Epoch 3/50
# 448/448 [==============================] - 30s 68ms/step - loss: 1.2988 - accuracy: 0.5006 - val_loss: 1.2088 - val_accuracy: 0.5361
# Epoch 4/50
# 448/448 [==============================] - 32s 71ms/step - loss: 1.2231 - accuracy: 0.5304 - val_loss: 1.1683 - val_accuracy: 0.5534
# Epoch 5/50
# 448/448 [==============================] - 31s 69ms/step - loss: 1.1686 - accuracy: 0.5533 - val_loss: 1.1349 - val_accuracy: 0.5670
# Epoch 6/50
# 448/448 [==============================] - 32s 72ms/step - loss: 1.1242 - accuracy: 0.5682 - val_loss: 1.1232 - val_accuracy: 0.5766
# Epoch 7/50
# 448/448 [==============================] - 32s 72ms/step - loss: 1.0895 - accuracy: 0.5884 - val_loss: 1.1198 - val_accuracy: 0.5769
# Epoch 8/50
# 448/448 [==============================] - 32s 72ms/step - loss: 1.0532 - accuracy: 0.6000 - val_loss: 1.0851 - val_accuracy: 0.5915
# Epoch 9/50
# 448/448 [==============================] - 31s 70ms/step - loss: 1.0175 - accuracy: 0.6150 - val_loss: 1.0723 - val_accuracy: 0.5960
# Epoch 10/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9805 - accuracy: 0.6289 - val_loss: 1.0671 - val_accuracy: 0.5999
# Epoch 11/50
# 448/448 [==============================] - 34s 76ms/step - loss: 0.9511 - accuracy: 0.6404 - val_loss: 1.0762 - val_accuracy: 0.5972
# Epoch 12/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.9187 - accuracy: 0.6529 - val_loss: 1.0652 - val_accuracy: 0.6039
# Epoch 13/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.8926 - accuracy: 0.6642 - val_loss: 1.0668 - val_accuracy: 0.5997
# Epoch 14/50
# 448/448 [==============================] - 31s 70ms/step - loss: 0.8654 - accuracy: 0.6773 - val_loss: 1.0469 - val_accuracy: 0.6064
# Epoch 15/50
# 448/448 [==============================] - 31s 68ms/step - loss: 0.8263 - accuracy: 0.6941 - val_loss: 1.0649 - val_accuracy: 0.6053
# Epoch 16/50
# 448/448 [==============================] - 30s 68ms/step - loss: 0.8054 - accuracy: 0.6976 - val_loss: 1.0673 - val_accuracy: 0.6069
# Epoch 17/50
# 448/448 [==============================] - 30s 67ms/step - loss: 0.7799 - accuracy: 0.7089 - val_loss: 1.0571 - val_accuracy: 0.6147
# Epoch 18/50
# 448/448 [==============================] - 30s 67ms/step - loss: 0.7493 - accuracy: 0.7204 - val_loss: 1.0731 - val_accuracy: 0.6211
# Epoch 19/50
# 448/448 [==============================] - 31s 70ms/step - loss: 0.7377 - accuracy: 0.7252 - val_loss: 1.0807 - val_accuracy: 0.6158
# Epoch 20/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.7077 - accuracy: 0.7380 - val_loss: 1.0859 - val_accuracy: 0.6101
# Epoch 21/50
# 448/448 [==============================] - 31s 70ms/step - loss: 0.6795 - accuracy: 0.7469 - val_loss: 1.0951 - val_accuracy: 0.6136
# Epoch 22/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.6713 - accuracy: 0.7522 - val_loss: 1.0948 - val_accuracy: 0.6176
# Epoch 23/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.6467 - accuracy: 0.7586 - val_loss: 1.0964 - val_accuracy: 0.6166
# Epoch 24/50
# 448/448 [==============================] - 30s 67ms/step - loss: 0.6368 - accuracy: 0.7633 - val_loss: 1.1011 - val_accuracy: 0.6226
# Epoch 25/50
# 448/448 [==============================] - 33s 73ms/step - loss: 0.6218 - accuracy: 0.7691 - val_loss: 1.1276 - val_accuracy: 0.6214
# Epoch 26/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.6109 - accuracy: 0.7729 - val_loss: 1.1245 - val_accuracy: 0.6162
# Epoch 27/50
# 448/448 [==============================] - 31s 68ms/step - loss: 0.5904 - accuracy: 0.7810 - val_loss: 1.1279 - val_accuracy: 0.6168
# Epoch 28/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.5795 - accuracy: 0.7852 - val_loss: 1.1160 - val_accuracy: 0.6166
# Epoch 29/50
# 448/448 [==============================] - 31s 69ms/step - loss: 0.5720 - accuracy: 0.7888 - val_loss: 1.1122 - val_accuracy: 0.6270
# Epoch 30/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.5518 - accuracy: 0.7931 - val_loss: 1.1408 - val_accuracy: 0.6161
# Epoch 31/50
# 448/448 [==============================] - 31s 69ms/step - loss: 0.5492 - accuracy: 0.7998 - val_loss: 1.1226 - val_accuracy: 0.6212
# Epoch 32/50
# 448/448 [==============================] - 31s 70ms/step - loss: 0.5362 - accuracy: 0.8040 - val_loss: 1.1425 - val_accuracy: 0.6263
# Epoch 33/50
# 448/448 [==============================] - 35s 78ms/step - loss: 0.5229 - accuracy: 0.8062 - val_loss: 1.1623 - val_accuracy: 0.6219
# Epoch 34/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.5158 - accuracy: 0.8108 - val_loss: 1.1424 - val_accuracy: 0.6243
# Epoch 35/50
# 448/448 [==============================] - 32s 70ms/step - loss: 0.5056 - accuracy: 0.8123 - val_loss: 1.1732 - val_accuracy: 0.6260
# Epoch 36/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.4930 - accuracy: 0.8208 - val_loss: 1.1702 - val_accuracy: 0.6272
# Epoch 37/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.4899 - accuracy: 0.8202 - val_loss: 1.1575 - val_accuracy: 0.6299
# Epoch 38/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.4931 - accuracy: 0.8194 - val_loss: 1.1391 - val_accuracy: 0.6256
# Epoch 39/50
# 448/448 [==============================] - 33s 73ms/step - loss: 0.4736 - accuracy: 0.8289 - val_loss: 1.1530 - val_accuracy: 0.6208
# Epoch 40/50
# 448/448 [==============================] - 32s 71ms/step - loss: 0.4731 - accuracy: 0.8280 - val_loss: 1.1934 - val_accuracy: 0.6183
# Epoch 41/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.4651 - accuracy: 0.8290 - val_loss: 1.1552 - val_accuracy: 0.6244
# Epoch 42/50
# 448/448 [==============================] - 33s 73ms/step - loss: 0.4502 - accuracy: 0.8364 - val_loss: 1.1948 - val_accuracy: 0.6260
# Epoch 43/50
# 448/448 [==============================] - 36s 80ms/step - loss: 0.4500 - accuracy: 0.8381 - val_loss: 1.2030 - val_accuracy: 0.6150
# Epoch 44/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.4383 - accuracy: 0.8399 - val_loss: 1.1911 - val_accuracy: 0.6272
# Epoch 45/50
# 448/448 [==============================] - 37s 81ms/step - loss: 0.4336 - accuracy: 0.8432 - val_loss: 1.2168 - val_accuracy: 0.6311
# Epoch 46/50
# 448/448 [==============================] - 31s 70ms/step - loss: 0.4376 - accuracy: 0.8423 - val_loss: 1.1951 - val_accuracy: 0.6180
# Epoch 47/50
# 448/448 [==============================] - 32s 70ms/step - loss: 0.4188 - accuracy: 0.8488 - val_loss: 1.2529 - val_accuracy: 0.6295
# Epoch 48/50
# 448/448 [==============================] - 33s 74ms/step - loss: 0.4157 - accuracy: 0.8517 - val_loss: 1.1923 - val_accuracy: 0.6260
# Epoch 49/50
# 448/448 [==============================] - 32s 72ms/step - loss: 0.4174 - accuracy: 0.8504 - val_loss: 1.2010 - val_accuracy: 0.6317
# Epoch 50/50
# 448/448 [==============================] - 33s 73ms/step - loss: 0.4095 - accuracy: 0.8546 - val_loss: 1.2344 - val_accuracy: 0.6250

# %%
tf.keras.utils.plot_model(emotion_model, to_file = "model.png", show_shapes = True, show_dtype = True)

# %% [markdown]
# # 5.Visualize Training Performance

# %%
print(emotion_model_info.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,2, figsize=(18, 6))
# Plot training & validation accuracy values
axes[0].plot(emotion_model_info.history['accuracy'])
axes[0].plot(emotion_model_info.history['val_accuracy'])
axes[0].set_title('Model accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
axes[1].plot(emotion_model_info.history['loss'])
axes[1].plot(emotion_model_info.history['val_loss'])
axes[1].set_title('Model loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # 6.Saving the model

# %%
emotion_model.save('facial_emotions_model.h5')

# %% [markdown]
# # 7. Test/Predict Image

# %%
from tensorflow.keras.preprocessing import image
img_path='../input/d/msambare/fer2013/test/happy/PrivateTest_10077120.jpg'
test_image=image.load_img(img_path,target_size=(48,48),color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
test_image=test_image.reshape(1,48,48,1)
classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
result=emotion_model.predict(test_image)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy
